# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

import os
import numpy as np
import pandas as pd
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow .keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %%
smooth = 1e-15
H = 256
W = 256

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding = 'same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, 3, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2,2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    # print(inputs.shape)
    x = Conv2DTranspose(num_filters, 2, strides = 2, padding = 'same')(inputs)
    # print(x.shape)
    x = Concatenate()([x, skip_features])
    # print(x.shape)
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    # print(s1.shape, s2.shape, s3.shape, s4.shape)
    # print(p1.shape, p2.shape, p3.shape, p4.shape)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    # print(d4.shape)

    outputs = Conv2D(1, 1, padding = 'same', activation ='sigmoid')(d4)
    # print(outputs.shape)

    model = Model (inputs, outputs, name = "UNET")
    return model

  
input_shape = (256, 256, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │     36,928 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │    147,584 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    590,080 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │  2,359,808 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  9,438,208 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │  2,097,664 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ activation_10[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    524,544 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    590,080 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │    131,200 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │    147,584 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │     32,832 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │     36,928 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         65 │ activation_17[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,055,297 (118.47 MB)
#  Trainable params: 31,043,521 (118.42 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %%
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection =  tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_dataset(path, split = 0.2):
    images = sorted(glob(os.path.join(path, "images","*.png")))
    masks = sorted(glob(os.path.join(path, "masks","*.png")))
    split_size = int(len(images)*split)
    train_x, valid_x = train_test_split(images, test_size=split_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=split_size, random_state=42)
    train_x, test_x = train_test_split(train_x, test_size=split_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=split_size, random_state=42)
    return (train_x,train_y), (valid_x,valid_y), (test_x,test_y)

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y
    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch = 2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
np.random.seed(42)
tf.random.set_seed(42)

create_dir("files")

batch_size = 16
lr = 1e-4
num_epochs = 500

model_path = os.path.join("files", "model.keras")
csv_path = os.path.join("files", "log.csv")
dataset_path = "/kaggle/input/brain-tumor-segmentation"

(train_x,train_y), (valid_x,valid_y), (test_x,test_y) = load_dataset(dataset_path)
print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")
print(f"Test: {len(test_x)} - {len(test_y)}")

train_dataset = tf_dataset(train_x, train_y, batch = batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch = batch_size)
# Out:
# Train: 1840 - 1840
# Valid: 612 - 612
# Test: 612 - 612

# %%
model = build_unet((H, W, 3))
model.compile(loss = dice_loss, optimizer=Adam(lr), metrics=[dice_coef])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
    CSVLogger(csv_path),
    EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)
]

model.fit(
    train_dataset,
    epochs = num_epochs,
    validation_data = valid_dataset,
    callbacks = callbacks
)
# Out:
# Epoch 1/500
# 2024-03-15 16:44:05.025753: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[64,64,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,256,256]{3,2,1,0}, f32[16,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-03-15 16:44:06.042232: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.016701901s
# Trying algorithm eng0{} for conv (f32[64,64,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,256,256]{3,2,1,0}, f32[16,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-03-15 16:44:08.735524: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[64,64,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,256,256]{3,2,1,0}, f32[16,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-03-15 16:44:09.744563: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.009222469s
# Trying algorithm eng0{} for conv (f32[64,64,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,256,256]{3,2,1,0}, f32[16,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-03-15 16:44:53.899851: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[64,128,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,256,256]{3,2,1,0}, f32[16,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-03-15 16:44:57.071549: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.171821507s
# Trying algorithm eng0{} for conv (f32[64,128,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,256,256]{3,2,1,0}, f32[16,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-03-15 16:45:01.245098: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[64,128,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,256,256]{3,2,1,0}, f32[16,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-03-15 16:45:04.366952: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.121969152s
# Trying algorithm eng0{} for conv (f32[64,128,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,256,256]{3,2,1,0}, f32[16,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710521111.177816     109 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 809ms/step - dice_coef: 0.0786 - loss: 0.9214
# Epoch 1: val_loss improved from inf to 0.98238, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 300s 1s/step - dice_coef: 0.0789 - loss: 0.9211 - val_dice_coef: 0.0176 - val_loss: 0.9824 - learning_rate: 1.0000e-04
# Epoch 2/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 811ms/step - dice_coef: 0.1868 - loss: 0.8132
# Epoch 2: val_loss did not improve from 0.98238
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 912ms/step - dice_coef: 0.1869 - loss: 0.8131 - val_dice_coef: 0.0165 - val_loss: 0.9835 - learning_rate: 1.0000e-04
# Epoch 3/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 811ms/step - dice_coef: 0.2483 - loss: 0.7517
# Epoch 3: val_loss improved from 0.98238 to 0.93073, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 926ms/step - dice_coef: 0.2484 - loss: 0.7516 - val_dice_coef: 0.0693 - val_loss: 0.9307 - learning_rate: 1.0000e-04
# Epoch 4/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.3116 - loss: 0.6884
# Epoch 4: val_loss improved from 0.93073 to 0.88461, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.3117 - loss: 0.6883 - val_dice_coef: 0.1154 - val_loss: 0.8846 - learning_rate: 1.0000e-04
# Epoch 5/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.3828 - loss: 0.6172
# Epoch 5: val_loss improved from 0.88461 to 0.65677, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.3829 - loss: 0.6171 - val_dice_coef: 0.3432 - val_loss: 0.6568 - learning_rate: 1.0000e-04
# Epoch 6/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.4495 - loss: 0.5505
# Epoch 6: val_loss improved from 0.65677 to 0.54540, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.4496 - loss: 0.5504 - val_dice_coef: 0.4546 - val_loss: 0.5454 - learning_rate: 1.0000e-04
# Epoch 7/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.5170 - loss: 0.4830
# Epoch 7: val_loss did not improve from 0.54540
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 913ms/step - dice_coef: 0.5171 - loss: 0.4829 - val_dice_coef: 0.4153 - val_loss: 0.5847 - learning_rate: 1.0000e-04
# Epoch 8/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.5796 - loss: 0.4204
# Epoch 8: val_loss improved from 0.54540 to 0.47814, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.5797 - loss: 0.4203 - val_dice_coef: 0.5219 - val_loss: 0.4781 - learning_rate: 1.0000e-04
# Epoch 9/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.6333 - loss: 0.3667
# Epoch 9: val_loss improved from 0.47814 to 0.44091, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.6333 - loss: 0.3667 - val_dice_coef: 0.5591 - val_loss: 0.4409 - learning_rate: 1.0000e-04
# Epoch 10/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.6751 - loss: 0.3249
# Epoch 10: val_loss improved from 0.44091 to 0.37339, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 926ms/step - dice_coef: 0.6751 - loss: 0.3249 - val_dice_coef: 0.6266 - val_loss: 0.3734 - learning_rate: 1.0000e-04
# Epoch 11/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.7143 - loss: 0.2857
# Epoch 11: val_loss improved from 0.37339 to 0.36404, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.7143 - loss: 0.2857 - val_dice_coef: 0.6360 - val_loss: 0.3640 - learning_rate: 1.0000e-04
# Epoch 12/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 811ms/step - dice_coef: 0.7384 - loss: 0.2616
# Epoch 12: val_loss improved from 0.36404 to 0.36319, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 926ms/step - dice_coef: 0.7385 - loss: 0.2615 - val_dice_coef: 0.6368 - val_loss: 0.3632 - learning_rate: 1.0000e-04
# Epoch 13/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.7640 - loss: 0.2360
# Epoch 13: val_loss improved from 0.36319 to 0.33092, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.7640 - loss: 0.2360 - val_dice_coef: 0.6691 - val_loss: 0.3309 - learning_rate: 1.0000e-04
# Epoch 14/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.7832 - loss: 0.2168
# Epoch 14: val_loss improved from 0.33092 to 0.30403, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.7832 - loss: 0.2168 - val_dice_coef: 0.6960 - val_loss: 0.3040 - learning_rate: 1.0000e-04
# Epoch 15/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.7958 - loss: 0.2042
# Epoch 15: val_loss improved from 0.30403 to 0.26818, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.7959 - loss: 0.2041 - val_dice_coef: 0.7318 - val_loss: 0.2682 - learning_rate: 1.0000e-04
# Epoch 16/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.8199 - loss: 0.1801
# Epoch 16: val_loss did not improve from 0.26818
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 913ms/step - dice_coef: 0.8199 - loss: 0.1801 - val_dice_coef: 0.6887 - val_loss: 0.3113 - learning_rate: 1.0000e-04
# Epoch 17/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.8333 - loss: 0.1667
# Epoch 17: val_loss improved from 0.26818 to 0.26468, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.8333 - loss: 0.1667 - val_dice_coef: 0.7353 - val_loss: 0.2647 - learning_rate: 1.0000e-04
# Epoch 18/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.8399 - loss: 0.1601
# Epoch 18: val_loss did not improve from 0.26468
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.8399 - loss: 0.1601 - val_dice_coef: 0.6630 - val_loss: 0.3370 - learning_rate: 1.0000e-04
# Epoch 19/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.8497 - loss: 0.1503
# Epoch 19: val_loss improved from 0.26468 to 0.24808, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.8496 - loss: 0.1504 - val_dice_coef: 0.7519 - val_loss: 0.2481 - learning_rate: 1.0000e-04
# Epoch 20/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.8600 - loss: 0.1400
# Epoch 20: val_loss did not improve from 0.24808
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 913ms/step - dice_coef: 0.8599 - loss: 0.1401 - val_dice_coef: 0.7365 - val_loss: 0.2635 - learning_rate: 1.0000e-04
# Epoch 21/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.8638 - loss: 0.1362
# Epoch 21: val_loss improved from 0.24808 to 0.22604, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.8638 - loss: 0.1362 - val_dice_coef: 0.7740 - val_loss: 0.2260 - learning_rate: 1.0000e-04
# Epoch 22/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.8811 - loss: 0.1189
# Epoch 22: val_loss improved from 0.22604 to 0.21662, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.8811 - loss: 0.1189 - val_dice_coef: 0.7834 - val_loss: 0.2166 - learning_rate: 1.0000e-04
# Epoch 23/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.8892 - loss: 0.1108
# Epoch 23: val_loss improved from 0.21662 to 0.21490, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.8892 - loss: 0.1108 - val_dice_coef: 0.7851 - val_loss: 0.2149 - learning_rate: 1.0000e-04
# Epoch 24/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.8957 - loss: 0.1043
# Epoch 24: val_loss improved from 0.21490 to 0.21166, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.8957 - loss: 0.1043 - val_dice_coef: 0.7883 - val_loss: 0.2117 - learning_rate: 1.0000e-04
# Epoch 25/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.8978 - loss: 0.1022
# Epoch 25: val_loss did not improve from 0.21166
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.8978 - loss: 0.1022 - val_dice_coef: 0.7755 - val_loss: 0.2245 - learning_rate: 1.0000e-04
# Epoch 26/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9020 - loss: 0.0980
# Epoch 26: val_loss improved from 0.21166 to 0.19859, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 927ms/step - dice_coef: 0.9020 - loss: 0.0980 - val_dice_coef: 0.8014 - val_loss: 0.1986 - learning_rate: 1.0000e-04
# Epoch 27/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9018 - loss: 0.0982
# Epoch 27: val_loss did not improve from 0.19859
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9017 - loss: 0.0983 - val_dice_coef: 0.7651 - val_loss: 0.2349 - learning_rate: 1.0000e-04
# Epoch 28/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.8771 - loss: 0.1229
# Epoch 28: val_loss did not improve from 0.19859
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.8770 - loss: 0.1230 - val_dice_coef: 0.7628 - val_loss: 0.2372 - learning_rate: 1.0000e-04
# Epoch 29/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.8981 - loss: 0.1019
# Epoch 29: val_loss did not improve from 0.19859
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.8982 - loss: 0.1018 - val_dice_coef: 0.7887 - val_loss: 0.2113 - learning_rate: 1.0000e-04
# Epoch 30/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9048 - loss: 0.0952
# Epoch 30: val_loss did not improve from 0.19859
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9048 - loss: 0.0952 - val_dice_coef: 0.7847 - val_loss: 0.2153 - learning_rate: 1.0000e-04
# Epoch 31/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9169 - loss: 0.0831
# Epoch 31: val_loss did not improve from 0.19859
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9169 - loss: 0.0831 - val_dice_coef: 0.7934 - val_loss: 0.2066 - learning_rate: 1.0000e-04
# Epoch 32/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9227 - loss: 0.0773
# Epoch 32: val_loss improved from 0.19859 to 0.19520, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 107s 928ms/step - dice_coef: 0.9227 - loss: 0.0773 - val_dice_coef: 0.8048 - val_loss: 0.1952 - learning_rate: 1.0000e-05
# Epoch 33/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9281 - loss: 0.0719
# Epoch 33: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9281 - loss: 0.0719 - val_dice_coef: 0.8039 - val_loss: 0.1961 - learning_rate: 1.0000e-05
# Epoch 34/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9302 - loss: 0.0698
# Epoch 34: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9302 - loss: 0.0698 - val_dice_coef: 0.8029 - val_loss: 0.1971 - learning_rate: 1.0000e-05
# Epoch 35/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9318 - loss: 0.0682
# Epoch 35: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 913ms/step - dice_coef: 0.9318 - loss: 0.0682 - val_dice_coef: 0.8021 - val_loss: 0.1979 - learning_rate: 1.0000e-05
# Epoch 36/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9333 - loss: 0.0667
# Epoch 36: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9333 - loss: 0.0667 - val_dice_coef: 0.8020 - val_loss: 0.1980 - learning_rate: 1.0000e-05
# Epoch 37/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9346 - loss: 0.0654
# Epoch 37: val_loss did not improve from 0.19520
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 915ms/step - dice_coef: 0.9346 - loss: 0.0654 - val_dice_coef: 0.8016 - val_loss: 0.1984 - learning_rate: 1.0000e-05
# Epoch 38/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9355 - loss: 0.0645
# Epoch 38: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9355 - loss: 0.0645 - val_dice_coef: 0.8001 - val_loss: 0.1999 - learning_rate: 1.0000e-06
# Epoch 39/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9359 - loss: 0.0641
# Epoch 39: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9359 - loss: 0.0641 - val_dice_coef: 0.8002 - val_loss: 0.1998 - learning_rate: 1.0000e-06
# Epoch 40/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9361 - loss: 0.0639
# Epoch 40: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9361 - loss: 0.0639 - val_dice_coef: 0.8001 - val_loss: 0.1999 - learning_rate: 1.0000e-06
# Epoch 41/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9363 - loss: 0.0637
# Epoch 41: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 915ms/step - dice_coef: 0.9363 - loss: 0.0637 - val_dice_coef: 0.8000 - val_loss: 0.2000 - learning_rate: 1.0000e-06
# Epoch 42/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9365 - loss: 0.0635
# Epoch 42: val_loss did not improve from 0.19520
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1e-07.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9365 - loss: 0.0635 - val_dice_coef: 0.7999 - val_loss: 0.2001 - learning_rate: 1.0000e-06
# Epoch 43/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9367 - loss: 0.0633
# Epoch 43: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9367 - loss: 0.0633 - val_dice_coef: 0.8000 - val_loss: 0.2000 - learning_rate: 1.0000e-07
# Epoch 44/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9367 - loss: 0.0633
# Epoch 44: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9367 - loss: 0.0633 - val_dice_coef: 0.8001 - val_loss: 0.1999 - learning_rate: 1.0000e-07
# Epoch 45/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9367 - loss: 0.0633
# Epoch 45: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9367 - loss: 0.0633 - val_dice_coef: 0.8001 - val_loss: 0.1999 - learning_rate: 1.0000e-07
# Epoch 46/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9368 - loss: 0.0632
# Epoch 46: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9367 - loss: 0.0632 - val_dice_coef: 0.8001 - val_loss: 0.1999 - learning_rate: 1.0000e-07
# Epoch 47/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9368 - loss: 0.0632
# Epoch 47: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9368 - loss: 0.0632 - val_dice_coef: 0.8001 - val_loss: 0.1999 - learning_rate: 1.0000e-07
# Epoch 48/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9368 - loss: 0.0632
# Epoch 48: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9368 - loss: 0.0632 - val_dice_coef: 0.8001 - val_loss: 0.1999 - learning_rate: 1.0000e-07
# Epoch 49/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9368 - loss: 0.0632
# Epoch 49: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9368 - loss: 0.0632 - val_dice_coef: 0.8001 - val_loss: 0.1999 - learning_rate: 1.0000e-07
# Epoch 50/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9369 - loss: 0.0631
# Epoch 50: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9368 - loss: 0.0632 - val_dice_coef: 0.8001 - val_loss: 0.1999 - learning_rate: 1.0000e-07
# Epoch 51/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9369 - loss: 0.0631
# Epoch 51: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9369 - loss: 0.0631 - val_dice_coef: 0.8001 - val_loss: 0.1999 - learning_rate: 1.0000e-07
# Epoch 52/500
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - dice_coef: 0.9369 - loss: 0.0631
# Epoch 52: val_loss did not improve from 0.19520
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 105s 914ms/step - dice_coef: 0.9369 - loss: 0.0631 - val_dice_coef: 0.8001 - val_loss: 0.1999 - learning_rate: 1.0000e-07

# %%
from tqdm import tqdm
from sklearn.metrics import f1_score, jaccard_score, precision_score, recall_score

# %%
def save_results(image, mask, y_pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = np.concatenate([mask, mask, mask], axis=-1)
    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    
    y_pred = y_pred * 255
    
    line = np.ones((H,7,3)) * 255
    
    cat_images = np.concatenate([image, mask, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
np.random.seed(42)
tf.random.set_seed(42)

create_dir("results")

model = tf.keras.models.load_model("/kaggle/working/files/model.keras", custom_objects = {"dice_loss": dice_loss, "dice_coef": dice_coef})

Score = []
for x, y in tqdm(zip(test_x, test_y), total = len(test_y)):
    name = x.split("/")[-1]
    
    image = cv2.imread(x, cv2.IMREAD_COLOR)
    image = cv2.resize(image, (W, H))
    x = image/255.0
    x = np.expand_dims(x,axis = 0)
    
    mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (W,H))
    
    y_pred = model.predict(x, verbose=0)[0]
    y_pred = np.squeeze(y_pred, axis = -1)
    y_pred = y_pred >= 0.5
    y_pred = y_pred.astype(np.int32)
    
    save_image_path = os.path.join("/kaggle/working/results",name)
    save_results(image, mask, y_pred, save_image_path)
    
    mask = mask/255.0
    mask = (mask>0.5).astype(np.int32).flatten()
    y_pred = y_pred.flatten()
    
    f1_value = f1_score(mask, y_pred, labels=[0,1], average = 'binary')
    jac_value = jaccard_score(mask, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
    precision_value = precision_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
    Score.append([name, f1_value, jac_value, recall_value, precision_value])
    
score = [s[1:]for s in Score]
score = np.mean(score, axis=0)
print(f"F1: {score[0]:0.5f}")
print(f"Jaccard: {score[1]:0.5f}")
print(f"Recall: {score[2]:0.5f}")
print(f"Precision: {score[3]:0.5f}")

df = pd.DataFrame(Score, columns=["Image", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score.csv")
# Out:
# 100%|██████████| 612/612 [02:11<00:00,  4.65it/s]
# F1: 0.76135
# Jaccard: 0.67523
# Recall: 0.75806
# Precision: 0.82129
